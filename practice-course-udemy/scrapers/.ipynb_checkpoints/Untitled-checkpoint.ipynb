# %%
import nested_html_tags_extraction

# %%
nested_html_tags_extraction


import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://en.wikipedia.org/wiki/Music"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "lxml")

div_notes = soup.find_all('div', {'role':'note'})
print(div_notes[0].find('a'))
# Out:
# <a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>

# %%
div_links = [div.find('a') for div in div_notes]

# %%
div_links
# Out:
# [<a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>,
#  <a href="/wiki/Musical_composition" title="Musical composition">Musical composition</a>,
#  <a href="/wiki/Musical_notation" title="Musical notation">Musical notation</a>,
#  <a href="/wiki/Musical_improvisation" title="Musical improvisation">Musical improvisation</a>,
#  <a href="/wiki/Music_theory" title="Music theory">Music theory</a>,
#  <a class="mw-redirect" href="/wiki/Aspect_of_music" title="Aspect of music">Aspect of music</a>,
#  <a href="/wiki/Timbre" title="Timbre">Timbre</a>,
#  <a href="/wiki/Strophic_form" title="Strophic form">Strophic form</a>,
#  <a href="/wiki/History_of_music" title="History of music">History of music</a>,
#  <a href="/wiki/Music_of_Egypt" title="Music of Egypt">Music of Egypt</a>,
#  <a href="/wiki/Music_of_Iran" title="Music of Iran">Music of Iran</a>,
# ...

# %%
len(div_links)
# Out:
# 33

# %%
div_notes = soup.find_all('div', {'role':'note'})
div_links = []

for div in div_notes:
    anchors = div.find_all('a')
    div_links.extend(anchors)

# %%
div_links
# Out:
# ['Music (disambiguation)',
#  'Musical composition',
#  'Musical notation',
#  'Musical improvisation',
#  'Music theory',
#  'Aspect of music',
#  'Timbre',
#  'Strophic form',
#  'History of music',
#  'Music of Egypt',
#  'Music of Iran',
#  'History of music in the biblical period',
#  '20th-century music',
#  'Performance',
#  'Ornament (music)',
#  'Philosophy of music',
#  'Music psychology',
#  'Cognitive neuroscience of music',
#  'Cognitive musicology',
#  'Psychoacoustics',
#  'Hearing (sense)',
#  'Evolutionary musicology',
#  'Culture in music cognition',
#  'Ethnomusicology',
#  'Sociomusicology',
#  'Women in music',
#  'Computer music',
#  'Music industry',
#  'Royalty_payment §\xa0Music_royalties',
#  'Music education',
#  'Ethnomusicology',
#  'Music therapy',
#  'Outline of music']

# %%
div_urls = [urljoin(base_site, l.get('href')) for l in div_links]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-0ce6055b94b3> in <module>
# ----> 1 div_urls = [urljoin(base_site, l.get('href')) for l in div_links]
#
# <ipython-input-16-0ce6055b94b3> in <listcomp>(.0)
# ----> 1 div_urls = [urljoin(base_site, l.get('href')) for l in div_links]
#
# ~/env/webscrape/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, attr)
#     883             raise AttributeError(
#     884                 "'%s' object has no attribute '%s'" % (
# --> 885                     self.__class__.__name__, attr))
#     886
#     887     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'get'

# %%
for div in div_notes:
    anchors = div.find_all('a')

# %%
anchors
# Out:
# [<a href="/wiki/Outline_of_music" title="Outline of music">Outline of music</a>,
#  <a href="/wiki/Index_of_music_articles" title="Index of music articles">Index of music articles</a>]

# %%
div_links
# Out:
# [<a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>,
#  <a href="/wiki/Musical_composition" title="Musical composition">Musical composition</a>,
#  <a href="/wiki/Musical_notation" title="Musical notation">Musical notation</a>,
#  <a href="/wiki/Musical_improvisation" title="Musical improvisation">Musical improvisation</a>,
#  <a href="/wiki/Music_theory" title="Music theory">Music theory</a>,
#  <a class="mw-redirect" href="/wiki/Aspect_of_music" title="Aspect of music">Aspect of music</a>,
#  <a href="/wiki/Timbre" title="Timbre">Timbre</a>,
#  <a href="/wiki/Strophic_form" title="Strophic form">Strophic form</a>,
#  <a href="/wiki/Binary_form" title="Binary form">Binary form</a>,
#  <a href="/wiki/Ternary_form" title="Ternary form">Ternary form</a>,
#  <a class="mw-redirect" href="/wiki/Rondo_form" title="Rondo form">Rondo form</a>,
# ...

# %%
div_links.extend(anchors)

# %%
div_links
# Out:
# [<a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>,
#  <a href="/wiki/Musical_composition" title="Musical composition">Musical composition</a>,
#  <a href="/wiki/Musical_notation" title="Musical notation">Musical notation</a>,
#  <a href="/wiki/Musical_improvisation" title="Musical improvisation">Musical improvisation</a>,
#  <a href="/wiki/Music_theory" title="Music theory">Music theory</a>,
#  <a class="mw-redirect" href="/wiki/Aspect_of_music" title="Aspect of music">Aspect of music</a>,
#  <a href="/wiki/Timbre" title="Timbre">Timbre</a>,
#  <a href="/wiki/Strophic_form" title="Strophic form">Strophic form</a>,
#  <a href="/wiki/Binary_form" title="Binary form">Binary form</a>,
#  <a href="/wiki/Ternary_form" title="Ternary form">Ternary form</a>,
#  <a class="mw-redirect" href="/wiki/Rondo_form" title="Rondo form">Rondo form</a>,
# ...

# %%
div_urls = [urljoin(base_site, l.get('href')) for l in div_links]

# %%
div_urls
# Out:
# ['https://en.wikipedia.org/wiki/Music_(disambiguation)',
#  'https://en.wikipedia.org/wiki/Musical_composition',
#  'https://en.wikipedia.org/wiki/Musical_notation',
#  'https://en.wikipedia.org/wiki/Musical_improvisation',
#  'https://en.wikipedia.org/wiki/Music_theory',
#  'https://en.wikipedia.org/wiki/Aspect_of_music',
#  'https://en.wikipedia.org/wiki/Timbre',
#  'https://en.wikipedia.org/wiki/Strophic_form',
#  'https://en.wikipedia.org/wiki/Binary_form',
#  'https://en.wikipedia.org/wiki/Ternary_form',
#  'https://en.wikipedia.org/wiki/Rondo_form',
#  'https://en.wikipedia.org/wiki/Variation_(music)',
#  'https://en.wikipedia.org/wiki/Musical_development',
#  'https://en.wikipedia.org/wiki/History_of_music',
#  'https://en.wikipedia.org/wiki/Music_of_Egypt',
#  'https://en.wikipedia.org/wiki/Music_of_Iran',
#  'https://en.wikipedia.org/wiki/Music_of_Afghanistan',
#  'https://en.wikipedia.org/wiki/Music_of_Tajikistan',
#  'https://en.wikipedia.org/wiki/Music_of_Sri_Lanka',
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://en.wikipedia.org/wiki/Music"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "lxml")

div_notes = soup.find_all('div', {'role':'note'})
div_links = []

for div in div_notes:
    anchors = div.find_all('a')
    div_links.extend(anchors)

div_urls = [urljoin(base_site, l.get('href')) for l in div_links]

par_text = []
i = 1
for url in div_urls:
    par_resp = requests.get(url)

    if par_resp.status_code == 200:
        print("URL #{0}: {1}".format(i+1,url))
    else:
        print("Status code {0}: Skipping URL #{1}: {2}".format(par_resp.status_code, i+1, url))
        i+=1
        continue
    par_html = par_resp.content
    par_soup = BeautifulSoup(par_html, 'lxml')
    pars = par_soup.find_all("p")
    text = [p.text for p in pars]
    par_text.append(text)
    i+=1

page_text = ["".join(text) for text in par_text]

url_to_text = dict(zip(div_urls, page_text))
# Out:
# URL #2: https://en.wikipedia.org/wiki/Music_(disambiguation)
# URL #3: https://en.wikipedia.org/wiki/Musical_composition
# URL #4: https://en.wikipedia.org/wiki/Musical_notation
# URL #5: https://en.wikipedia.org/wiki/Musical_improvisation
# URL #6: https://en.wikipedia.org/wiki/Music_theory
# URL #7: https://en.wikipedia.org/wiki/Aspect_of_music
# URL #8: https://en.wikipedia.org/wiki/Timbre
# URL #9: https://en.wikipedia.org/wiki/Strophic_form
# URL #10: https://en.wikipedia.org/wiki/Binary_form
# URL #11: https://en.wikipedia.org/wiki/Ternary_form
# URL #12: https://en.wikipedia.org/wiki/Rondo_form
# URL #13: https://en.wikipedia.org/wiki/Variation_(music)
# URL #14: https://en.wikipedia.org/wiki/Musical_development
# URL #15: https://en.wikipedia.org/wiki/History_of_music
# URL #16: https://en.wikipedia.org/wiki/Music_of_Egypt
# URL #17: https://en.wikipedia.org/wiki/Music_of_Iran
# URL #18: https://en.wikipedia.org/wiki/Music_of_Afghanistan
# ...

# %%
print(url_to_text['https://en.wikipedia.org/wiki/Music_therapy'])
# Out:
# Music therapy is an evidence-based clinical use of musical interventions to improve clients' quality of life. Music therapists use music and its many facets— physical, emotional, mental, social, aesthetic, and spiritual— to help clients improve their health in cognitive, motor, emotional, communicative, social, sensory, and educational domains by using both active and receptive music experiences. These experiences include improvisation, re-creation, composition, receptive methods, and discussion of music.
# Some common music therapy practices include developmental work (communication, motor skills, etc.) with individuals with special needs, songwriting and listening in reminiscence, orientation work with the elderly, processing and relaxation work, and rhythmic entrainment for physical rehabilitation in stroke victims. Music therapy is used in some medical hospitals, cancer centers, schools, alcohol and drug recovery programs, psychiatric hospitals, and correctional facilities.[1]
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20?innings=2&filter=full"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "html.parser")

full_commentary = soup.find_all('div', {'class':'content match-commentary__content'})
div_contents = []

for div in full_commentary:
    commentry_div = div.find_all('div')
    div_contents.append(commentry_div)

# %%
div_contents
# Out:
# [[<div class="commentary-item end-of-over" data-reactid="180"><h4 data-reactid="181"><!-- react-text: 182 -->END OF OVER:<!-- /react-text --><div data-reactid="183"><!-- react-text: 184 -->16 | 1 Run 1 Wkt | RCB: 82/10 <!-- /react-text --><!-- react-text: 185 -->(141 runs required from 29 balls, RR: 5.40, RRR: 29.17)<!-- /react-text --></div></h4><ul class="two-col-table" data-reactid="186"><li data-reactid="187">Praveen Kumar<span>18 (15b)</span></li></ul><ul class="two-col-table" data-reactid="188"><li data-reactid="189">Laxmi Shukla<span>1.1-0-12-1</span></li><li data-reactid="190">Ishant Sharma<span>3-0-7-1</span></li></ul></div>,
#   <div data-reactid="183"><!-- react-text: 184 -->16 | 1 Run 1 Wkt | RCB: 82/10 <!-- /react-text --><!-- react-text: 185 -->(141 runs required from 29 balls, RR: 5.40, RRR: 29.17)<!-- /react-text --></div>,
# ...

# %%
div_text = [div.get('text') for div in div_contents]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-969ffc7d06dd> in <module>
# ----> 1 div_text = [div.get('text') for div in div_contents]
#
# <ipython-input-34-969ffc7d06dd> in <listcomp>(.0)
# ----> 1 div_text = [div.get('text') for div in div_contents]
#
# ~/env/webscrape/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    2126         """Raise a helpful exception to explain a common code fix."""
#    2127         raise AttributeError(
# -> 2128             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2129         )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
div_contents[0].text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-c4640504a75d> in <module>
# ----> 1 div_contents[0].text
#
# ~/env/webscrape/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    2126         """Raise a helpful exception to explain a common code fix."""
#    2127         raise AttributeError(
# -> 2128             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2129         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20?innings=2&filter=full"

response = requests.get(base_site)
print(response.status_code)

html = response.content
soup = BeautifulSoup(html, "lxml")

with open('espncricinfo_commentary.html', 'wb') as file:
    file.write(soup.prettify('utf-8'))
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20?innings=2&filter=full"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "html.parser")

full_commentary = soup.find_all('div', {'class':'content match-commentary__content'})

# %%
div_contents
# Out:
# [[<div class="description" data-reactid="205">Shukla to Joshi, <b>OUT</b>, <b>caught at the extra cover fence</b> and it's all over! Fittingly, it's Brendon McCullum who has taken the final catch. Going across him and Joshi wanted to swat this over long-off, ends up getting it towards the end of the bat and it spoons to McCullum.</div>]]

# %%
full_commentary
# Out:
# [<div class="content match-commentary__content" data-reactid="179"><div class="commentary-item end-of-over" data-reactid="180"><h4 data-reactid="181"><!-- react-text: 182 -->END OF OVER:<!-- /react-text --><div data-reactid="183"><!-- react-text: 184 -->16 | 1 Run 1 Wkt | RCB: 82/10 <!-- /react-text --><!-- react-text: 185 -->(141 runs required from 29 balls, RR: 5.40, RRR: 29.17)<!-- /react-text --></div></h4><ul class="two-col-table" data-reactid="186"><li data-reactid="187">Praveen Kumar<span>18 (15b)</span></li></ul><ul class="two-col-table" data-reactid="188"><li data-reactid="189">Laxmi Shukla<span>1.1-0-12-1</span></li><li data-reactid="190">Ishant Sharma<span>3-0-7-1</span></li></ul></div><div class="commentary-item pre" data-reactid="191"><div data-reactid="192"><p class="comment" data-reactid="193"><b>11.10 pm:</b> Well that brings us to the end of this IPL opener. We've witnessed possibly the start of history, the start of a tournament that could alter dynamics in world cr
# ...

# %%
full_commentary.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-4eb909c80744> in <module>
# ----> 1 full_commentary.text
#
# ~/env/webscrape/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    2126         """Raise a helpful exception to explain a common code fix."""
#    2127         raise AttributeError(
# -> 2128             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2129         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for element in full_commentary:
    element.extract()

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-icon-fonts" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <link href="https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20" rel="canonical"/>
# <title>Get Ball by Ball Commentary of Royal Challengers Bangalore vs Kolkata Knight Riders 1st match (N), Indian Premier League 2020 | ESPNcricinfo.com</title>
# ...

# %%
full_commentary
# Out:
# [<div class="content match-commentary__content" data-reactid="179"><div class="commentary-item end-of-over" data-reactid="180"><h4 data-reactid="181"><!-- react-text: 182 -->END OF OVER:<!-- /react-text --><div data-reactid="183"><!-- react-text: 184 -->16 | 1 Run 1 Wkt | RCB: 82/10 <!-- /react-text --><!-- react-text: 185 -->(141 runs required from 29 balls, RR: 5.40, RRR: 29.17)<!-- /react-text --></div></h4><ul class="two-col-table" data-reactid="186"><li data-reactid="187">Praveen Kumar<span>18 (15b)</span></li></ul><ul class="two-col-table" data-reactid="188"><li data-reactid="189">Laxmi Shukla<span>1.1-0-12-1</span></li><li data-reactid="190">Ishant Sharma<span>3-0-7-1</span></li></ul></div><div class="commentary-item pre" data-reactid="191"><div data-reactid="192"><p class="comment" data-reactid="193"><b>11.10 pm:</b> Well that brings us to the end of this IPL opener. We've witnessed possibly the start of history, the start of a tournament that could alter dynamics in world cr
# ...

# %%
texts = [a.text for a in full_commentary]

# %%
texts
# Out:
# ['END OF OVER:16 | 1 Run 1 Wkt | RCB: 82/10 (141 runs required from 29 balls, RR: 5.40, RRR: 29.17)Praveen Kumar18 (15b)Laxmi Shukla1.1-0-12-1Ishant Sharma3-0-7-111.10 pm: Well that brings us to the end of this IPL opener. We\'ve witnessed possibly the start of history, the start of a tournament that could alter dynamics in world cricket significantly. It had all the ingredients, and Brendon McCullum just came and added some tangy spices.To no one\'s surprise, Brendon McCullum is the Man of the Match. "I can\'t ask for any bigger start to the tournament. There were a few nerves when I went out there in the afternoon. In the end, the victory was fantastic. So much hype and excitement coming into this IPL, and to be part of the first game, walking out with Sourav was a pretty surreal feeling. We gave ourselves about two overs to see what\'s going on. Once you get into a bit of a rhythm - it\'s a small ground and good pitch - I was able to continue the momentum. It was everything the ex
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20?innings=2&filter=full"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "html.parser")

match_commentary_content = soup.find_all('div', {'class':'content match-commentary__content'})

commentary_texts = [a.text for a in full_commentary]

page_text = ["".join(text) for text in par_text]

print(page_text)
# Out:
# ['Music is an art form consisting of sound and silence, expressed through time.\nMusic may also refer to:\n', '\nMusical composition, music composition, or simply composition, can refer to an original piece or work of music,[1] either vocal or instrumental, the structure of a musical piece, or to the process of creating or writing a new piece of music. People who create new compositions are called composers. Composers of primarily songs are usually called songwriters;[2][3] with songs, the person who writes lyrics for a song is the lyricist. In many cultures, including Western classical music, the act of composing typically includes the creation of music notation, such as a sheet music "score," which is then performed by the composer or by other musicians. In popular music and traditional music, songwriting may involve the creation of a basic outline of the song, called the lead sheet, which sets out the melody, lyrics and chord progression. In classical music, orchestration (choosin
# ...

# %%
commentary_texts = [a.text for a in full_commentary]

# %%
commentary_texts
# Out:
# ['END OF OVER:16 | 1 Run 1 Wkt | RCB: 82/10 (141 runs required from 29 balls, RR: 5.40, RRR: 29.17)Praveen Kumar18 (15b)Laxmi Shukla1.1-0-12-1Ishant Sharma3-0-7-111.10 pm: Well that brings us to the end of this IPL opener. We\'ve witnessed possibly the start of history, the start of a tournament that could alter dynamics in world cricket significantly. It had all the ingredients, and Brendon McCullum just came and added some tangy spices.To no one\'s surprise, Brendon McCullum is the Man of the Match. "I can\'t ask for any bigger start to the tournament. There were a few nerves when I went out there in the afternoon. In the end, the victory was fantastic. So much hype and excitement coming into this IPL, and to be part of the first game, walking out with Sourav was a pretty surreal feeling. We gave ourselves about two overs to see what\'s going on. Once you get into a bit of a rhythm - it\'s a small ground and good pitch - I was able to continue the momentum. It was everything the ex
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20?innings=2&filter=full"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "html.parser")

match_commentary_content = soup.find_all('div', {'class':'content match-commentary__content'})

commentary_texts = [a.text for a in match_commentary_content]

for text in commentary_texts:
    print(text)
    print("\n")
# Out:
# END OF OVER:16 | 1 Run 1 Wkt | RCB: 82/10 (141 runs required from 29 balls, RR: 5.40, RRR: 29.17)Praveen Kumar18 (15b)Laxmi Shukla1.1-0-12-1Ishant Sharma3-0-7-111.10 pm: Well that brings us to the end of this IPL opener. We've witnessed possibly the start of history, the start of a tournament that could alter dynamics in world cricket significantly. It had all the ingredients, and Brendon McCullum just came and added some tangy spices.To no one's surprise, Brendon McCullum is the Man of the Match. "I can't ask for any bigger start to the tournament. There were a few nerves when I went out there in the afternoon. In the end, the victory was fantastic. So much hype and excitement coming into this IPL, and to be part of the first game, walking out with Sourav was a pretty surreal feeling. We gave ourselves about two overs to see what's going on. Once you get into a bit of a rhythm - it's a small ground and good pitch - I was able to continue the momentum. It was everything the expectati
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

base_site = "https://www.espncricinfo.com/series/19832/commentary/1220949/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-n-indian-premier-league-retrolive-2019-20?innings=2&filter=full"

response = requests.get(base_site)

html = response.content
soup = BeautifulSoup(html, "html.parser")

match_commentary_content = soup.find('article', {'data-reactid':'141'})

commentary_strings = [article.text for article in match_commentary_content]
print(len(commentary_strings))
# Out:
# 1
